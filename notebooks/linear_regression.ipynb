# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import sys
sys.path.append('../')

from src.linear_regression import LinearRegression
from src.optimizers import SGD, Adagrad, Adam

# %%
theta = np.array([[0.5]])
b = np.array([-5])

def f(x: np.ndarray, theta: np.ndarray, b: np.ndarray) -> np.ndarray:
    return x @ theta.T + b + np.random.normal(0, 0.1, (x.shape[0], 1))
    # return x @ theta.T + b + np.random.normal(0, 1, (x.shape[0], 1))

# %%
X = np.linspace(-1, 1, 100)[:, None]
Y = f(X, theta, b)

# %%
plt.title("Data")
plt.scatter(X, Y)

# %%
linear_regression = LinearRegression()
linear_regression.fit(X, Y, epochs=100, batch_size=1, optimizer=SGD(lr=1e-2))
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 2301.97it/s, loss=0.333]

# %%
plt.plot(linear_regression.losses)

# %%
pred_Y = linear_regression.predict(X)

plt.title("Pred")
plt.scatter(X, Y)
plt.plot(X, pred_Y)

# %%
linear_regression.display_contour_plot()

# %%
linear_regression = LinearRegression()
linear_regression.fit(X, Y, epochs=100, batch_size=1, optimizer=Adagrad(lr=1.0))
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 2907.48it/s, loss=0.000454]

# %%
pred_Y = linear_regression.predict(X)

plt.title("Pred")
plt.scatter(X, Y)
plt.plot(X, pred_Y)

# %%
linear_regression.display_contour_plot()

# %%
linear_regression = LinearRegression()
linear_regression.fit(X, Y, epochs=100, batch_size=8, optimizer=Adam(lr=1e-1))
# Out:
# ...
# 100%|██████████| 100/100 [00:00<00:00, 2916.99it/s, loss=0.00805]

# %%
pred_Y = linear_regression.predict(X)

plt.title("Pred")
plt.scatter(X, Y)
plt.plot(X, pred_Y)

# %%
linear_regression.display_contour_plot()
